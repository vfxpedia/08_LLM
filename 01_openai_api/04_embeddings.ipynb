343, 0.03154605254530907, 0.00904629472643137, -0.08944233506917953, 0.002803771523758769, 0.043561387807130814, 0.0563189834356308, 0.08962790668010712, -0.04147377982735634, -0.010008913464844227, -0.01525112520903349, 0.019669892266392708, 0.0026022593956440687, 0.03708980605006218, -0.040685128420591354, -0.06100450083613396, 0.02695331908762455, -0.040314000099897385, -0.006210629362612963, -0.015517874620854855, 0.021699508652091026, 0.06745288521051407, -0.009898734278976917, -0.02825227379798889, -0.017095176503062248, -0.005813403986394405, 0.0314764678478241, -0.008605577982962132, 0.07455074787139893, -0.007063068449497223, 0.012514040805399418, 0.04530106112360954, -0.012780790217220783, 0.015332309529185295, -0.01021767407655716, 0.02437860332429409, -0.0260486900806427, -0.03602280840277672, 0.023961082100868225, 0.01498437486588955, -0.0007230511982925236, -0.016178950667381287, -0.044697973877191544, -0.03815680742263794, 0.0015294617041945457, -0.012119715102016926, -0.06239623576402664, -0.02089926041662693, 0.027208469808101654, -0.03405117988586426, 0.01899721845984459, -0.013766604475677013, -0.05543754994869232, -0.020458543673157692, -0.0007324744365178049, -0.022905681282281876, -0.034863028675317764, -0.060679759830236435, 0.03664908930659294, -0.010414836928248405, -0.10113293677568436, 0.0024819320533424616, -0.03488622233271599, 0.02808990515768528, 0.029412055388092995, -0.01302434504032135, -0.017825840041041374, 0.020852869376540184, -0.04029080271720886, 0.01969308778643608, -0.004256397485733032, 0.0298295766 ...
# 1536

# %% [markdown]
# ### 음식 리뷰 데이터 활용

# %%
import pandas as pd

df = pd.read_csv("fine_food_reviews_1k.csv")
display(df.head())
print(df.shape)
# Out:
#    Unnamed: 0        Time   ProductId          UserId  Score  \
# 0           0  1351123200  B003XPF9BO  A3R7JR3FMEBXQB      5
# 1           1  1351123200  B003JK537S  A3JBPC3WFUT5ZP      1
# 2           2  1351123200  B000JMBE7M   AQX1N6A51QOKG      4
# 3           3  1351123200  B004AHGBX4  A2UY46X0OSNVUQ      3
# 4           4  1351123200  B001BORBHO  A1AFOYZ9HSM2CZ      5
#
#                                              Summary  \
# 0  where does one  start...and stop... with a tre...
# 1                                  Arrived in pieces
# 2          It isn't blanc mange, but isn't bad . . .
# 3        These also have SALT and it's not sea salt.
# 4                             Happy with the product
#
#                                                 Text
# 0  Wanted to save some to bring to my Chicago fam...
# 1  Not pleased at all. When I opened the box, mos...
# 2  I'm not sure that custard is really custard wi...
# 3  I like the fact that you can see what you're g...
# 4  My dog was suffering with itchy skin.  He had ...
# (1000, 7)

# %%
import tiktoken

gpt4o_encoding = tiktoken.encoding_for_model("text-embedding-3-small")
df['n_tokens'] = df['Text'].apply(lambda x: len(gpt4o_encoding.encode(x)))
df[['Text', 'n_tokens']].head()
# Out:
#                                                 Text  n_tokens
# 0  Wanted to save some to bring to my Chicago fam...        34
# 1  Not pleased at all. When I opened the box, mos...        26
# 2  I'm not sure that custard is really custard wi...       249
# 3  I like the fact that you can see what you're g...       223
# 4  My dog was suffering with itchy skin.  He had ...        77

# %%
df['n_tokens'].describe()
# Out:
# count    1000.000000
# mean       85.637000
# std        73.562903
# min        22.000000
# 25%        38.000000
# 50%        60.000000
# 75%       106.500000
# max       623.000000
# Name: n_tokens, dtype: float64

# %%
# 임베딩 처리
def texts_to_embedding(texts):

    # 전처리
    texts = [text.replace("\n", " ") for text in texts]

    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=texts,
    )

    return [data.embedding for data in response.data]

# %%
df['embedding'] = texts_to_embedding(df['Text'].tolist())

# %%
df['embedding']
# Out:
# 0      [0.01677853614091873, -0.008555943146348, -0.0...
# 1      [-0.005216312129050493, 0.040469057857990265, ...
# 2      [0.005564768798649311, -0.012970144860446453, ...
# 3      [-0.016292475163936615, 0.008886804804205894, ...
# 4      [-0.004322985652834177, -0.06378211826086044, ...
#                              ...
# 995    [0.01907997578382492, -0.037228021770715714, -...
# 996    [-0.037051208317279816, -0.013656404800713062,...
# 997    [-0.04671481251716614, -0.07131096720695496, -...
# 998    [-0.014545817859470844, -0.03374110162258148, ...
# 999    [0.014047509990632534, -0.013696948997676373, ...
# Name: embedding, Length: 1000, dtype: object

# %%
embed_df = df['embedding'].to_frame('embedding')
embed_df.index = df['Text']
embed_df
# Out:
#                                                                                             embedding
# Text
# Wanted to save some to bring to my Chicago fami...  [0.01677853614091873, -0.008555943146348, -0.0...
# Not pleased at all. When I opened the box, most...  [-0.005216312129050493, 0.040469057857990265, ...
# I'm not sure that custard is really custard wit...  [0.005564768798649311, -0.012970144860446453, ...
# I like the fact that you can see what you're ge...  [-0.016292475163936615, 0.008886804804205894, ...
# My dog was suffering with itchy skin.  He had b...  [-0.004322985652834177, -0.06378211826086044, ...
# ...                                                                                               ...
# I have ordered these raisins multiple times.  T...  [0.01907997578382492, -0.037228021770715714, -...
# My dog will come in from outside when I am trai...  [-0.037051208317279816, -0.013656404800713062,...
# Wolfgang Puck's Jamaica Me Crazy is that wonder...  [-0.04671481251716614, -0.07131096720695496, -...
# Great product for the price. Mix with the Asian...  [-0.014545817859470844, -0.03374110162258148, ...
# My first experience with Maui Coffee was bringi...  [0.014047509990632534, -0.013696948997676373, ...
#
# [1000 rows x 1 columns]

# %% [markdown]
# - 코사인 유사도 측정

# %%
import numpy as np

cos_sim = lambda a, b: np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def get_similar_texts(query, embed_df, top_n=5):
    query_embed = texts_to_embedding(query)[0]
    embed_df['cos_sim'] = embed_df['embedding'].apply(lambda x: cos_sim(x, query_embed))

    return embed_df.sort_values('cos_sim', ascending=False).head(top_n)

# %%
get_similar_texts(["pizza"], embed_df)
# Out:
#                                                                                             embedding  \
# Text
# Makes very good break sticks.. Also can be used...  [-0.0031160328071564436, 0.0032433217857033014...
# The Barilla Mezze Penne with spicy marinara sau...  [-0.023196613416075706, -0.03185791149735451, ...
# Love these packs. I have made pretzel dogs, bit...  [0.021732978522777557, -0.02915913611650467, -...
# try it & we shared with the familys/all han thu...  [0.016222583130002022, -0.04311098903417587, -...
# About time, this is the best organic gluten fre...  [-0.05429341644048691, -0.0073051839135587215,...
#
#                                                      cos_sim
# Text
# Makes very good break sticks.. Also can be used...  0.415317
# The Barilla Mezze Penne with spicy marinara sau...  0.355800
# Love these packs. I have made pretzel dogs, bit...  0.350850
# try it & we shared with the familys/all han thu...  0.341087
# About time, this is the best organic gluten fre...  0.339322
